# sqft_lot       1.000000 -0.005201    0.021604  0.074710  ...  0.113621
# floors        -0.005201  1.000000    0.023698  0.029444  ...  0.458183
# waterfront     0.021604  0.023698    1.000000  0.401857  ...  0.082775
# view           0.074710  0.029444    0.401857  1.000000  ...  0.251321
# condition     -0.008958 -0.263768    0.016653  0.045990  ... -0.144674
# grade          0.113621  0.458183    0.082775  0.251321  ...  1.000000
# sqft_above     0.183512  0.523885    0.072075  0.167649  ...  0.755923
# sqft_basement  0.015286 -0.245705    0.080588  0.276947  ...  0.168392
# yr_built       0.053080  0.489319   -0.026161 -0.053440  ...  0.446963
# yr_renovated   0.007644  0.006338    0.092885  0.103917  ...  0.014414
# zipcode       -0.129574 -0.059121    0.030285  0.084827  ... -0.184862
# lat           -0.085683  0.049614   -0.014274  0.006157  ...  0.114084
# long           0.229521  0.125419   -0.041910 -0.078400  ...  0.198372
# sqft_living15  0.144608  0.279885    0.086463  0.280439  ...  0.713202
# sqft_lot15     0.718557 -0.011269    0.030703  0.072575  ...  0.119248
#
#                sqft_above  sqft_basement  yr_built  yr_renovated   zipcode  \
# id              -0.010842      -0.005151  0.021380     -0.016907 -0.008224
# date            -0.024421      -0.016130  0.003248     -0.024070  0.001235
# price            0.605567       0.323816  0.054012      0.126434 -0.053203
# bedrooms         0.477600       0.303093  0.154178      0.018841 -0.152668
# bathrooms        0.685342       0.283770  0.506019      0.050739 -0.203866
# sqft_living      0.876597       0.435043  0.318049      0.055363 -0.199430
# sqft_lot         0.183512       0.015286  0.053080      0.007644 -0.129574
# floors           0.523885      -0.245705  0.489319      0.006338 -0.059121
# waterfront       0.072075       0.080588 -0.026161      0.092885  0.030285
# view             0.167649       0.276947 -0.053440      0.103917  0.084827
# condition       -0.158214       0.174105 -0.361417     -0.060618  0.003026
# grade            0.755923       0.168392  0.446963      0.014414 -0.184862
# sqft_above       1.000000      -0.051943  0.423898      0.023285 -0.261190
# sqft_basement   -0.051943       1.000000 -0.133124      0.071323  0.074845
# yr_built         0.423898      -0.133124  1.000000     -0.224874 -0.346869
# yr_renovated     0.023285       0.071323 -0.224874      1.000000  0.064357
# zipcode         -0.261190       0.074845 -0.346869      0.064357  1.000000
# lat             -0.000816       0.110538 -0.148122      0.029398  0.267048
# long             0.343803      -0.144765  0.409356     -0.068372 -0.564072
# sqft_living15    0.731870       0.200355  0.326229     -0.002673 -0.279033
# sqft_lot15       0.194050       0.017276  0.070958      0.007854 -0.147221
#
#                     lat      long  sqft_living15  sqft_lot15
# id            -0.001891  0.020799      -0.002901   -0.138798
# date          -0.029770 -0.000301      -0.022752    0.000154
# price          0.307003  0.021626       0.585379    0.082447
# bedrooms      -0.008931  0.129473       0.391638    0.029244
# bathrooms      0.024573  0.223042       0.568634    0.087175
# sqft_living    0.052529  0.240223       0.756420    0.183286
# sqft_lot      -0.085683  0.229521       0.144608    0.718557
# floors         0.049614  0.125419       0.279885   -0.011269
# waterfront    -0.014274 -0.041910       0.086463    0.030703
# view           0.006157 -0.078400       0.280439    0.072575
# condition     -0.014941 -0.106500      -0.092824   -0.003406
# grade          0.114084  0.198372       0.713202    0.119248
# sqft_above    -0.000816  0.343803       0.731870    0.194050
# sqft_basement  0.110538 -0.144765       0.200355    0.017276
# yr_built      -0.148122  0.409356       0.326229    0.070958
# yr_renovated   0.029398 -0.068372      -0.002673    0.007854
# zipcode        0.267048 -0.564072      -0.279033   -0.147221
# lat            1.000000 -0.135512       0.048858   -0.086419
# long          -0.135512  1.000000       0.334605    0.254451
# sqft_living15  0.048858  0.334605       1.000000    0.183192
# sqft_lot15    -0.086419  0.254451       0.183192    1.000000
#
# [21 rows x 21 columns]

# %%
y = data["price"]
X = data.drop(["price"], axis=1)

# %%
y.head(15)
# Out:
# 0      221900.0
# 1      538000.0
# 2      180000.0
# 3      604000.0
# 4      510000.0
# 5     1225000.0
# 6      257500.0
# 7      291850.0
# 8      229500.0
# 9      323000.0
# 10     662500.0
# 11     468000.0
# 12     310000.0
# 13     400000.0
# 14     530000.0
# Name: price, dtype: float64

# %%
X.head(15)
# Out:
#             id      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 
# array([991075.89654804, 731305.8055758 , 303309.43248562, ...,
#        783310.47529911, 534995.43685045, 137657.62141456])

# %% [raw]
# Реализация метрик и сравнение с базовыми.

# %%
y_pred = lr.predict(X_test)
prediction = pd.DataFrame(data=y_pred, columns = ["Lin_multi"])

def MAE(y_test, y_pred):
    f = lambda x,y: np.abs(x-y) 
    return np.sum(list(map(f, y_test, y_pred)))/len(y_test)

def MSE(y_test, y_pred):
    f = lambda x,y: pow(x-y, 2) 
    return np.sum(list(map(f, y_test, y_pred)))/len(y_test)

def RMSE(y_test, y_pred):
    f = lambda x,y: pow(x-y, 2) 
    return sqrt(np.sum(list(map(f, y_test, y_pred)))/len(y_test))

def MAPE(y_test, y_pred):
    f = lambda x,y: np.abs((x-y)/x) 
    return sqrt(np.sum(list(map(f, y_test, y_pred)))/len(y_test))

def R2(MSE, y_test):
    y_mean = np.mean(y_test)
    f = lambda x: pow(x, 2) 
    return 1 - MSE/(np.sum(list(map(f, np.array(y_test) - y_mean)))/len(y_test))
    
MSE_var=MSE(y_test, y_pred)
print(f'MAE: {mean_absolute_error(y_test, y_pred)}\t\t {MAE(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}\t\t {MSE(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}\t {RMSE(y_test, y_pred)}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_test, y_pred))}\t {MAPE(y_test, y_pred)}')
print(f'R^2: {lr.score(X_test, y_test)}\t\t {R2(MSE_var, y_test)}')
lr.coef_
# Out:
# MAE: 127282.14673079431		 127282.14673079431
# MSE: 40286370389.33639		 40286370389.33639
# RMSE: 200714.64916476922	 200714.64916476922
# MAPE: 0.5053736424106197	 0.5053736424106197
# R^2: 0.6958885217431726		 0.6958885217431726
# array([-1.36327871e-06,  3.17712695e+00, -3.37372930e+04,  4.31116312e+04,
#         1.08904097e+02,  1.23510436e-01,  6.18254298e+03,  6.23838705e+05,
#         5.05235712e+04,  2.78054065e+04,  9.50788642e+04,  7.21657709e+01,
#         3.67383261e+01, -2.61623552e+03,  2.36049086e+01, -5.93378395e+02,
#         6.08032568e+05, -2.25672913e+05,  2.31960052e+01, -3.98722667e-01])

# %%
parameters = {'alpha': np.arange(0, 1, 0.01)}

ridge_optimal = RandomizedSearchCV(Ridge(), parameters).fit(X_train, y_train)
ridge_optimal.best_params_
# Out:
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.63841e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.619e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.62733e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.62789e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.61236e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.11434e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.09644e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.10412e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.10463e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.09034e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.93963e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.92226e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.92971e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.93022e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.91632e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.64741e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.62211e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.63297e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.63369e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.61345e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.68659e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.6641e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.67374e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.67439e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.6564e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.24067e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.22567e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.23183e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.23257e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.22041e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.18368e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.17732e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.18003e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.18023e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.17512e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.51189e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.48992e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.49934e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.49998e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.4824e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.46372e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.44481e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.45292e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.45346e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.43834e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.90045e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.88027e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.88894e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.88951e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.87337e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=4.74193e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# {'alpha': 0.68}

# %%
ridge = Ridge(alpha=0.68).fit(X_train, y_train)
y_pred = ridge.predict(X_test)
prediction.insert(loc= 0 , column='Lin_multi_ridge', value=y_pred)

print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_test, y_pred))}')
print(f'R^2: {ridge.score(X_test, y_test)}')
ridge.coef_
# Out:
# MAE: 127257.58631553894
# MSE: 40274421300.23531
# RMSE: 200684.8805970079
# MAPE: 0.5052869992580655
# R^2: 0.6959787223523423
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=4.74193e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# array([-1.36619540e-06,  3.17618762e+00, -3.37609692e+04,  4.31093219e+04,
#         1.08922236e+02,  1.22874904e-01,  6.25059064e+03,  6.19783426e+05,
#         5.06841462e+04,  2.77866543e+04,  9.51285634e+04,  7.21309341e+01,
#         3.67888153e+01, -2.61890987e+03,  2.36160129e+01, -5.91621006e+02,
#         6.06496094e+05, -2.24789026e+05,  2.31746734e+01, -3.99154833e-01])

# %%
lasso = Lasso(alpha=0.68).fit(X_train, y_train)
y_pred = lasso.predict(X_test)
prediction.insert(loc= 0 , column='Lin_multi_lasso', value=y_pred)

print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_test, y_pred))}')
print(f'R^2: {lasso.score(X_test, y_test)}')
# Out:
# MAE: 127281.01896747402
# MSE: 40286004856.73336
# RMSE: 200713.73858491442
# MAPE: 0.5053693238044364
# R^2: 0.6958912810550486
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.187e+14, tolerance: 2.340e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
elastic = ElasticNet(alpha=0.68).fit(X_train, y_train)
y_pred = elastic.predict(X_test)
prediction.insert(loc= 0 , column='Lin_multi_elastic', value=y_pred)

print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_test, y_pred))}')
print(f'R^2: {ridge.score(X_test, y_test)}')
# Out:
# MAE: 143593.9620055467
# MSE: 49038092105.80932
# RMSE: 221445.46079296662
# MAPE: 0.5405731925986315
# R^2: 0.6959787223523423
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.608e+14, tolerance: 2.340e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
prediction
# Out:
#       Lin_multi_elastic  Lin_multi_lasso  Lin_multi_ridge     Lin_multi
# 0          8.471431e+05     9.910564e+05     9.905519e+05  9.910759e+05
# 1          6.511076e+05     7.313014e+05     7.311215e+05  7.313058e+05
# 2          3.509984e+05     3.033094e+05     3.033516e+05  3.033094e+05
# 3          3.120672e+05     4.220341e+05     4.216838e+05  4.220426e+05
# 4          1.189566e+06     1.148405e+06     1.148469e+06  1.148407e+06
# ...                 ...              ...              ...           ...
# 4318       3.354951e+05     3.077048e+05     3.078190e+05  3.077015e+05
# 4319       6.817971e+05     8.624146e+05     8.620143e+05  8.624326e+05
# 4320       8.730300e+05     7.833153e+05     7.837586e+05  7.833105e+05
# 4321       4.716516e+05     5.349904e+05     5.348283e+05  5.349954e+05
# 4322       1.671490e+05     1.376615e+05     1.377220e+05  1.376576e+05
#
# [4323 rows x 4 columns]

# %% [markdown]
# регрессия с одним предиктором

# %%
y_single = data["price"]
x_single = data[["price","sqft_living"]]
x_single
# Out:
#           price  sqft_living
# 0      221900.0         1180
# 1      538000.0         2570
# 2      180000.0          770
# 3      604000.0         1960
# 4      510000.0         1680
# ...         ...          ...
# 21608  360000.0         1530
# 21609  400000.0         2310
# 21610  402101.0         1020
# 21611  400000.0         1600
# 21612  325000.0         1020
#
# [21613 rows x 2 columns]

# %%
X_single_train, X_single_test, y_single_train, y_single_test = train_test_split(X, y, test_size=0.2)
lr = LinearRegression().fit(X_single_train, y_single_train)
y_single_pred = lr.predict(X_single_test)
prediction.insert(loc= 0 , column='Lin_single', value=y_single_pred)

print(f'MAE: {mean_absolute_error(y_single_test, y_single_pred)}')
print(f'MSE: {mean_squared_error(y_single_test, y_single_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_single_test, y_single_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_single_test, y_single_pred))}')
print(f'R^2: {lr.score(X_single_test, y_single_test)}')
# Out:
# MAE: 122619.65760768918
# MSE: 38386811273.860466
# RMSE: 195925.52481455923
# MAPE: 0.503381887859538
# R^2: 0.7016609702587318

# %%
parameters = {'alpha': np.arange(0, 1, 0.01)}

ridge_optimal = RandomizedSearchCV(Ridge(), parameters).fit(X_single_train, y_single_train)
ridge_optimal.best_params_
# Out:
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.62275e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.60905e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.62094e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.60602e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=2.61981e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.59411e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.56525e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.59106e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.55997e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.58958e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.16745e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.13048e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.16356e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.12373e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.16166e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.85634e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.82612e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.85315e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.82061e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=5.8516e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.32152e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.30438e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.3197e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.30122e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=3.31879e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.42968e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.39135e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.42564e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.38435e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.42367e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.8356e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.82612e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.83457e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.82435e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=1.83406e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.77929e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.73917e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.77507e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.73185e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=7.77303e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.74593e-26): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.69918e-26): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.7361e-26): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.68577e-26): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.7294e-26): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.61536e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.56563e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.60973e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.55608e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=9.60691e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.20763e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# {'alpha': 0.89}

# %%
ridge = Ridge(alpha=0.89).fit(X_single_train, y_single_train)
y_pred = ridge.predict(X_single_test)
prediction.insert(loc= 0 , column='Lin_single_ridge', value=y_pred)

print(f'MAE: {mean_absolute_error(y_single_test, y_single_pred)}')
print(f'MSE: {mean_squared_error(y_single_test, y_single_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_single_test, y_single_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_single_test, y_single_pred))}')
print(f'R^2: {ridge.score(X_single_test, y_single_test)}')
# Out:
# MAE: 122619.65760768918
# MSE: 38386811273.860466
# RMSE: 195925.52481455923
# MAPE: 0.503381887859538
# R^2: 0.7016770882945934
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.20763e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
lasso = Lasso(alpha=0.89).fit(X_single_train, y_single_train)
y_pred = lasso.predict(X_single_test)
prediction.insert(loc= 0 , column='Lin_single_lasso', value=y_pred)

print(f'MAE: {mean_absolute_error(y_single_test, y_single_pred)}')
print(f'MSE: {mean_squared_error(y_single_test, y_single_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_single_test, y_single_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_single_test, y_single_pred))}')
print(f'R^2: {ridge.score(X_single_test, y_single_test)}')
# Out:
# MAE: 122619.65760768918
# MSE: 38386811273.860466
# RMSE: 195925.52481455923
# MAPE: 0.503381887859538
# R^2: 0.7016770882945934
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.220e+14, tolerance: 2.356e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
elastic = ElasticNet(alpha=0.31).fit(X_single_train, y_single_train)
y_pred = elastic.predict(X_single_test)
prediction.insert(loc= 0 , column='Lin_single_elastic', value=y_pred)

print(f'MAE: {mean_absolute_error(y_single_test, y_single_pred)}')
print(f'MSE: {mean_squared_error(y_single_test, y_single_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_single_test, y_single_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_single_test, y_single_pred))}')
print(f'R^2: {ridge.score(X_single_test, y_single_test)}')
# Out:
# MAE: 122619.65760768918
# MSE: 38386811273.860466
# RMSE: 195925.52481455923
# MAPE: 0.503381887859538
# R^2: 0.7016770882945934
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.432e+14, tolerance: 2.356e+11
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Полиномиальная регрессия

# %%
p = PolynomialFeatures(2)

X_p=p.fit_transform(X)
X_p
# Out:
# array([[1.00000000e+00, 7.12930052e+09, 2.01410130e+07, ...,
#         1.79560000e+06, 7.57100000e+06, 3.19225000e+07],
#        [1.00000000e+00, 6.41410019e+09, 2.01412090e+07, ...,
#         2.85610000e+06, 1.29099100e+07, 5.83543210e+07],
#        [1.00000000e+00, 5.63150040e+09, 2.01502250e+07, ...,
#         7.39840000e+06, 2.19286400e+07, 6.49958440e+07],
#        ...,
#        [1.00000000e+00, 1.52330014e+09, 2.01406230e+07, ...,
#         1.04040000e+06, 2.04714000e+06, 4.02804900e+06],
#        [1.00000000e+00, 2.91310100e+08, 2.01501160e+07, ...,
#         1.98810000e+06, 1.81467000e+06, 1.65636900e+06],
#        [1.00000000e+00, 1.52330016e+09, 2.01410150e+07, ...,
#         1.04040000e+06, 1.38414000e+06, 1.84144900e+06]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_p, y, test_size=0.2)

lr2 = LinearRegression().fit(X_train, y_train)

y_pred = lr2.predict(X_test)
prediction.insert(loc= 0 , column='Lin_polinom', value=y_pred)

print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_test, y_pred))}')
print(f'R^2: {lr2.score(X_test, y_test)}')
# Out:
# MAE: 113764.36258911865
# MSE: 29630619944.9754
# RMSE: 172135.46974686944
# MAPE: 0.4824477286741441
# R^2: 0.7715318491330114

# %% [markdown]
# результат стал лучше, попробуем применить регуляризаторы

# %%
parameters = {'alpha': np.arange(0, 1, 0.01)}

ridge_optimal = RandomizedSearchCV(Ridge(), parameters).fit(X_train, y_train)
ridge_optimal.best_params_
# Out:
# {'alpha': 0.74}

# %%
lr2 = Lasso(alpha=0.74).fit(X_train, y_train)

y_pred = lr2.predict(X_test)
prediction.insert(loc= 0 , column='Lin_polinom_lasso', value=y_pred)

print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_test, y_pred))}')
print(f'R^2: {lr2.score(X_test, y_test)}')
# Out:
# MAE: 107790.54269030661
# MSE: 26837335294.04893
# RMSE: 163821.04655400335
# MAPE: 0.4682327552629812
# R^2: 0.7930695888167378
# C:\Users\1\Jupyter Notebook\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.539e+14, tolerance: 2.352e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
lr2 = Ridge(alpha=0.74).fit(X_train, y_train)

y_pred = lr2.predict(X_test)
prediction.insert(loc= 0 , column='Lin_polinom_ridge', value=y_pred)

print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_test, y_pred))}')
print(f'R^2: {lr2.score(X_test, y_test)}')
# Out:
# MAE: 122107.6761826468
# MSE: 33020982959.586094
# RMSE: 181716.76576360833
# MAPE: 0.5024117412596331
# R^2: 0.7453903114211997

# %% [markdown]
# самый точный прогноз - полиномиальная регрессия с лассо

# %% [markdown]
# попробуем составить прогноз на основе наших прогнозов

# %%
prediction
# Out:
#       Lin_polinom_ridge  Lin_polinom_lasso    Lin_polinom  Lin_single_elastic  \
# 0         428613.417020      359917.756884  357969.769269       675196.736295
# 1         843943.118963      828541.058189  732477.672351       498653.815874
# 2         313484.591990      248719.173349  254548.538117       440534.490293
# 3         220050.575045      245154.672679  207995.136855       276608.039765
# 4         579564.560656      505281.305226  451581.687665       285650.406866
# ...                 ...                ...            ...                 ...
# 4318      485088.399556      476049.858977  445325.290137       472942.317604
# 4319      298246.247573      326801.780275  247553.277217       453628.466205
# 4320      698394.255274      731037.276206  734580.333837       362990.864193
# 4321      475391.326861      480893.098978  468776.568233       449298.625209
# 4322      186131.870292      204378.328854  196741.127372       575773.277692
#
#       Lin_single_lasso  Lin_single_ridge     Lin_single  Lin_multi_elastic  \
# 0        759831.330192     760014.549438  759838.913301       8.471431e+05
# 1        559731.105402     559620.768930  559740.823036       6.511076e+05
# 2        470843.002744     470680.179150  470850.254609       3.509984e+05
# 3        196771.985500     197088.642727  196765.042434       3.120672e+05
# 4        345252.770439     345054.831971  345253.602129       1.189566e+06
# ...                ...               ...            ...                ...
# 4318     405938.411555     406165.201517  405925.824905       3.354951e+05
# 4319     361220.315275     361830.897362  361194.771227       6.817971e+05
# 4320     375706.604958     375813.069087  375701.182924       8.730300e+05
# 4321     327111.656306     327566.112833  327095.368943       4.716516e+05
# 4322     517206.554221     517398.028956  517194.713530       1.671490e+05
#
#       Lin_multi_lasso  Lin_multi_ridge     Lin_multi
# 0        9.910564e+05     9.905519e+05  9.910759e+05
# 1        7.313014e+05     7.311215e+05  7.313058e+05
# 2        3.033094e+05     3.033516e+05  3.033094e+05
# 3        4.220341e+05     4.216838e+05  4.220426e+05
# 4        1.148405e+06     1.148469e+06  1.148407e+06
# ...               ...              ...           ...
# 4318     3.077048e+05     3.078190e+05  3.077015e+05
# 4319     8.624146e+05     8.620143e+05  8.624326e+05
# 4320     7.833153e+05     7.837586e+05  7.833105e+05
# 4321     5.349904e+05     5.348283e+05  5.349954e+05
# 4322     1.376615e+05     1.377220e+05  1.376576e+05
#
# [4323 rows x 11 columns]

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(prediction, y_test, test_size=0.2)

lr3 = LinearRegression().fit(X1_train, y1_train)

y1_pred = lr3.predict(X1_test)

print(f'MAE: {mean_absolute_error(y1_test, y1_pred)}')
print(f'MSE: {mean_squared_error(y1_test, y1_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y1_test, y1_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y1_test, y1_pred))}')
print(f'R^2: {lr3.score(X1_test, y1_test)}')
# Out:
# MAE: 107420.68113660485
# MSE: 26400327598.437363
# RMSE: 162481.77620409423
# MAPE: 0.46285512644733734
# R^2: 0.8474872926394932

# %% [markdown]
# Этот вариант оказался самым точным, ура!
