# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

# %% [markdown]
# ## Задание 1

# %%
data1, data_y1 = make_classification(n_samples=500, n_classes=2, n_features=2, n_redundant=0, n_clusters_per_class=2, flip_y=0, random_state=69)
data2, data_y2 = make_classification(n_samples=600, n_classes=2, n_features=5,class_sep=3, n_redundant=0,n_informative=2, n_clusters_per_class=2, flip_y=0, random_state=69)
data3, data_y3 = make_classification(n_samples=700, n_classes=3, n_features=4, n_redundant=0,n_informative=4 ,class_sep = 3, n_clusters_per_class=2, flip_y=0, random_state=69)

# %%
plt.scatter(data1[:, 0], data1[:, 1], marker="o", c=data_y1, s=25, edgecolor="k")
plt.show()
plt.scatter(data2[:, 0], data2[:, 1], marker="o", c=data_y2, s=25, edgecolor="k")
plt.show()
plt.scatter(data3[:, 0], data3[:, 1], marker="o", c=data_y3, s=25, edgecolor="k")
plt.show()

# %%
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics.cluster import rand_score
from sklearn.metrics import completeness_score

def metric (km,d,dy):
    print("Rand_Score::", rand_score(km, dy))
    print("Completeness Score:", completeness_score(km, dy))
    print("Silhouette_score:", silhouette_score(d, km))
    print("Davies-Bouldin Score:", davies_bouldin_score(d, km))

# %% [markdown]
# # Kmeans

# %%
from sklearn.cluster import KMeans

#Метод локтя:

inertias = []
for i in range(2, 10):
    m = KMeans(i, n_init='auto').fit(data1)
    inertias.append(m.inertia_)
plt.plot(range(2,10), inertias)
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %%
#Метод силуэта:
ss = []
for i in range(2, 10):
  ss.append(silhouette_score(data1, KMeans(i, n_init='auto').fit(data1).labels_))
plt.plot(range(2,10), ss)
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %%
kmeans1 = KMeans(2, n_init='auto').fit(data1)
plt.scatter(data1[:,0], data1[:,1], c=kmeans1.labels_)
plt.scatter(kmeans1.cluster_centers_[:,0], kmeans1.cluster_centers_[:,1], s=100, c='red')
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
import pickle

pkl_filename = "KMEASN.pkl" 
with open(pkl_filename, 'wb') as file: 
    pickle.dump(kmeans1, file)

# %%
metric(kmeans1.labels_,data1,data_y1)
# Out:
# Rand_Score:: 0.5005691382765531
# Completeness Score: 0.0022704685578503986
# Silhouette_score: 0.38921720193336373
# Davies-Bouldin Score: 1.1920862864014377

# %%
#Метод локтя:
inertias = []
for i in range(2, 10):
  m = KMeans(i, n_init='auto').fit(data2)
  inertias.append(m.inertia_)
plt.plot(range(2,10), inertias)
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# ...

# %%
#Метод силуэта:
ss = []
for i in range(2, 10):
  ss.append(silhouette_score(data2, KMeans(i, n_init='auto').fit(data2).labels_))
plt.plot(range(2,10), ss)
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# ...

# %%
kmeans2 = KMeans(2, n_init='auto').fit(data2)
plt.scatter(data2[:,0], data2[:,1], c=kmeans2.labels_)
plt.scatter(kmeans2.cluster_centers_[:,0], kmeans2.cluster_centers_[:,1], s=100, c='red')
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
metric(kmeans2.labels_,data2,data_y2)
# Out:
# Rand_Score:: 1.0
# Completeness Score: 1.0
# Silhouette_score: 0.3774376268535811
# Davies-Bouldin Score: 1.2064631706719333

# %%
#Метод локтя:
inertias = []

for i in range(2, 10):
  m = KMeans(i, n_init='auto').fit(data2)
  inertias.append(m.inertia_)

plt.plot(range(2,10), inertias)
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# ...

# %%
#Метод силуэта:
from sklearn.metrics import silhouette_score

ss = []

for i in range(2, 10):
  ss.append(silhouette_score(data3, KMeans(i, n_init='auto').fit(data3).labels_))

plt.plot(range(2,10), ss)
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# ...

# %%
kmeans3 = KMeans(2,n_init='auto').fit(data3)
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
plt.scatter(data3[:,0], data3[:,1], c=kmeans3.labels_)
plt.scatter(kmeans3.cluster_centers_[:,0], kmeans3.cluster_centers_[:,1], s=100, c='red')

# %%
metric(kmeans3.labels_,data3,data_y3)
# Out:
# Rand_Score:: 0.49928877988963827
# Completeness Score: 5.5808933857331064e-06
# Silhouette_score: 0.44591377569211965
# Davies-Bouldin Score: 1.010283616454307

# %% [markdown]
# # AffinityPropagation

# %%
from sklearn.cluster import AffinityPropagation

AP1 = AffinityPropagation(max_iter= 200,preference=-10, damping=0.7).fit(data1)

plt.scatter(data1[:,0], data1[:,1], c=AP1.labels_)
plt.scatter(AP1.cluster_centers_[:,0], AP1.cluster_centers_[:,1], s=100, c='red')


metric(AP1.labels_,data1,data_y1)
# Out:
# Rand_Score:: 0.5624769539078156
# Completeness Score: 0.6720620058227914
# Silhouette_score: 0.438233337258734
# Davies-Bouldin Score: 0.7078556791200992

# %% [markdown]
# "preference", которые контролируют количество экземпляров и "damping factor", который снижает ответственность сообщений

# %%
AP2 = AffinityPropagation(max_iter= 200,preference=-10, damping=0.7).fit(data2)

plt.scatter(data2[:,0], data2[:,1], c=AP2.labels_)
plt.scatter(AP2.cluster_centers_[:,0], AP2.cluster_centers_[:,1], s=100, c='red')

metric(AP2.labels_,data2,data_y2)
# Out:
# Rand_Score:: 0.5209794101279911
# Completeness Score: 1.0
# Silhouette_score: 0.17204852850637087
# Davies-Bouldin Score: 1.2233829915231698

# %%
AP3 = AffinityPropagation(max_iter= 200,preference=-10, damping=0.7).fit(data3)

plt.scatter(data3[:,0], data3[:,1], c=AP3.labels_)
plt.scatter(AP3.cluster_centers_[:,0], AP3.cluster_centers_[:,1], s=100, c='red')

metric(AP3.labels_,data3,data_y3)
# Out:
# Rand_Score:: 0.6901737175556918
# Completeness Score: 0.9859953493386922
# Silhouette_score: 0.2497382761277343
# Davies-Bouldin Score: 1.098072974546649

# %% [markdown]
# ## DB-SCAN
#
#
# - Находим точки в $\epsilon$  окрестности каждой точки и выделяем основные точки с более чем minPts соседями.
#
# - Находим связные компоненты основных точек на графе соседей, игнорируя все неосновные точки.
#
# - Назначаем каждую неосновную ближайшему кластеру, если кластер является $\epsilon$ -соседним, в противном случае считаем точку шумом.

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np
nbrs = NearestNeighbors(n_neighbors=4).fit(data1)
distances, indices = nbrs.kneighbors(data1)
distances = np.mean(distances, axis=1)
distances = np.sort(distances)

plt.plot(distances)

# %%
from sklearn.cluster import DBSCAN

dbscan1 = DBSCAN(eps = 0.2 ,min_samples=4).fit(data1)

plt.scatter(data1[:,0], data1[:,1], c=dbscan1.labels_)
metric(dbscan1.labels_,data1,data_y1)
# Out:
# Rand_Score:: 0.5416673346693387
# Completeness Score: 0.2839998887005973
# Silhouette_score: -0.07274582449835483
# Davies-Bouldin Score: 1.8820994571627156

# %%
nbrs = NearestNeighbors(n_neighbors=4).fit(data2)
distances, indices = nbrs.kneighbors(data2)

distances = np.mean(distances, axis=1)
distances = np.sort(distances)
plt.plot(distances)

# %%
dbscan2 = DBSCAN(eps=1.2 ,min_samples=4).fit(data2)

plt.scatter(data2[:,0], data2[:,1], c=dbscan2.labels_)
metric(dbscan2.labels_,data2,data_y2)
# Out:
# Rand_Score:: 0.6239454646633278
# Completeness Score: 0.7471731094190176
# Silhouette_score: 0.03672672603390725
# Davies-Bouldin Score: 1.7659812667874333

# %%
nbrs = NearestNeighbors(n_neighbors=4).fit(data3)
distances, indices = nbrs.kneighbors(data3)

distances = np.mean(distances, axis=1)
distances = np.sort(distances)

plt.plot(distances)

# %%
dbscan3 = DBSCAN(eps=1.2 ,min_samples=4).fit(data3)

plt.scatter(data3[:,0], data3[:,1], c=dbscan3.labels_)
metric(dbscan3.labels_,data3,data_y3)
# Out:
# Rand_Score:: 0.8097118332311465
# Completeness Score: 0.9323386439552298
# Silhouette_score: 0.5115003067072834
# Davies-Bouldin Score: 1.567058674285007

# %% [markdown]
# # Gaussian Mixtures

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.mixture import GaussianMixture

# %%
param_grid = {
    'n_components': range(2,5)
}

gridseach = GridSearchCV(GaussianMixture(), param_grid=param_grid)
gridseach.fit(data1)
gridseach.best_params_
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %%
gm1 = GaussianMixture(n_components=4).fit(data1)
pred1 = gm1.predict(data1)

plt.scatter(data1[:,0], data1[:,1], c=gm1.predict(data1))
plt.scatter(gm1.means_[:,0], gm1.means_[:,1], s=100, c='red')
metric(pred1,data1,data_y1)
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Rand_Score:: 0.7194869739478958
# Completeness Score: 0.8406035922237713
# Silhouette_score: 0.48089298129948477
# Davies-Bouldin Score: 0.7972793740128581

# %%
gridseach.fit(data2)
gridseach.best_params_
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %%
gm2 = GaussianMixture(n_components=4).fit(data2)
pred2 = gm2.predict(data2)

plt.scatter(data2[:,0], data2[:,1], c=gm2.predict(data2))
plt.scatter(gm2.means_[:,0], gm2.means_[:,1], s=100, c='red')
metric(pred2,data2,data_y2)
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# Rand_Score:: 0.7495826377295493
# Completeness Score: 1.0
# Silhouette_score: 0.5354280094225993
# Davies-Bouldin Score: 0.7044065275642402

# %%
gridseach.fit(data3)
gridseach.best_params_
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# ...

# %%
gm3 = GaussianMixture(n_components=4).fit(data3)

pred3 = gm3.predict(data3)
plt.scatter(data3[:,0], data3[:,1], c=gm3.predict(data3))
plt.scatter(gm3.means_[:,0], gm3.means_[:,1], s=100, c='red')
metric(pred3,data3,data_y3)
# Out:
# C:\Users\djego\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# Rand_Score:: 0.6661925199264255
# Completeness Score: 0.5000027904466927
# Silhouette_score: 0.477537103879221
# Davies-Bouldin Score: 0.6950847739257932

# %% [markdown]
# ## Иерархическая кластеризация

# %%
from scipy.cluster import hierarchy

clusters = hierarchy.linkage(data1, method="ward")
plt.figure(figsize=(8, 6))
dendrogram = hierarchy.dendrogram(clusters)
plt.axhline(20, color='red', linestyle='--');
plt.axhline(30, color='crimson');

# %%
from sklearn.cluster import AgglomerativeClustering

clustering1 = AgglomerativeClustering(n_clusters=2, linkage="ward").fit(data1)
plt.scatter(data1[:,0], data1[:,1], c=clustering1.labels_)
metric(clustering1.labels_,data1,data_y1)
# Out:
# Rand_Score:: 0.6472625250501002
# Completeness Score: 0.3471165674959533
# Silhouette_score: 0.4105448988401486
# Davies-Bouldin Score: 1.10161430785268

# %%
clusters = hierarchy.linkage(data2, method="ward")

plt.figure(figsize=(8, 6))
dendrogram = hierarchy.dendrogram(clusters)
plt.axhline(32, color='red', linestyle='--');
plt.axhline(25, color='crimson');

# %%
clustering2 = AgglomerativeClustering(n_clusters=3, linkage="ward").fit(data2)
plt.scatter(data2[:,0], data2[:,1], c=clustering2.labels_)
metric(clustering2.labels_,data2,data_y2)
# Out:
# Rand_Score:: 0.8747968836950473
# Completeness Score: 0.9999999999999993
# Silhouette_score: 0.4166777504235015
# Davies-Bouldin Score: 0.8474057442803788

# %%
clusters = hierarchy.linkage(data3, method="ward")

plt.figure(figsize=(8, 6))
dendrogram = hierarchy.dendrogram(clusters)
plt.axhline(40, color='red', linestyle='--');
plt.axhline(30, color='crimson');

# %%
clustering3 = AgglomerativeClustering(n_clusters=2, linkage="ward").fit(data3)
plt.scatter(data3[:,0], data3[:,1], c=clustering3.labels_)
metric(clustering3.labels_,data3,data_y3)
# Out:
# Rand_Score:: 0.49928877988963827
# Completeness Score: 5.5808933857331064e-06
# Silhouette_score: 0.44591377569211965
# Davies-Bouldin Score: 1.010283616454307

# %% [markdown]
# # KMEANS

# %%
class KMEANS:
    def __init__(self, num_clusters, max_iterations=100):
        self.num_clusters = num_clusters
        self.max_iterations = max_iterations
    
    def _calculate_euclidean_distance(self, centroids, points):
        return np.sqrt(np.sum((centroids[:, np.newaxis] - points) ** 2, axis=2))
    
    def _update_centroids(self, data):
        distances = self._calculate_euclidean_distance(data, self.centroids)
        clusters = np.argmin(distances, axis=1)
            
        return np.array([np.mean(data[clusters == i], axis=0) for i in range(self.num_clusters)])

    def fit(self, data):
        self.centroids = data[np.random.choice(data.shape[0], self.num_clusters, replace=False)]

        for _ in range(self.max_iterations):
            new_centroids = self._update_centroids(data)

            if np.all(self.centroids == new_centroids):
                break

            self.centroids = new_centroids
            
    def predict(self, data):
        distances = self._calculate_euclidean_distance(data, self.centroids)
        return np.argmin(distances, axis=1)

# %%
kmeans = KMEANS(num_clusters=2)
kmeans.fit(data1)
pred = kmeans.predict(data1)
plt.scatter(data1[:,0], data1[:,1], c= pred)
plt.scatter(kmeans.centroids[:, 0], kmeans.centroids[:, 1], c='r')

metric(pred,data1,data_y1)
# Out:
# Rand_Score:: 0.5005691382765531
# Completeness Score: 0.0022704685578503986
# Silhouette_score: 0.38921720193336373
# Davies-Bouldin Score: 1.1920862864014377

# %% [markdown]
# # Задание 2

# %%
import pandas as pd

# %%
data=pd.read_csv('../data/laba4.csv')
# data=data.dropna()
# data=data.drop(['Unnamed: 0'],axis=1)
# dict1 = {'Yes': '1', 'No': '0'}

# data['Fire Alarm'] = data['Fire Alarm'].map(dict1)
# data['Fire Alarm']=data['Fire Alarm'].astype(int)

# %%
from sklearn.cluster import KMeans

inertias = []
for i in range(2, 10):
    m = KMeans(i, n_init='auto').fit(data)
    inertias.append(m.inertia_)
plt.plot(range(2,10), inertias)

# %%
import numpy as np
df_y=np.array(data['Price'])[:1500]
df = np.array(data)[:1500]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # Kmeans

# %%
from sklearn.cluster import KMeans

#Метод локтя:

inertias = []
for i in range(2, 10):
    m = KMeans(i, n_init='auto').fit(data)
    inertias.append(m.inertia_)
plt.plot(range(2,10), inertias)

# %%
kmeans = KMeans(2, n_init='auto').fit(df)
plt.scatter(df[:,0], df[:,1], c=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=100, c='red')
# metric(kmeans.labels_,df,df_y)
import pickle 
 
pkl_filename = "Kmeans.pkl" 
with open(pkl_filename, 'wb') as file: 
    pickle.dump(kmeans, file)

# %% [markdown]
# # Иерархия

# %%
clusters = hierarchy.linkage(df, method="ward")
plt.figure(figsize=(8, 6))
dendrogram = hierarchy.dendrogram(clusters)
plt.axhline(20, color='red', linestyle='--');
plt.axhline(30, color='crimson');

# %%
clustering = AgglomerativeClustering(n_clusters=2, linkage="ward").fit(df)
plt.scatter(df[:,0], df[:,1], c=clustering.labels_)
metric(clustering.labels_,df,df_y)
# Out:
# Rand_Score:: 0.5317767400489215
# Completeness Score: 1.0
# Silhouette_score: 0.5691750764107947
# Davies-Bouldin Score: 0.5179118882448144

# %% [markdown]
# # DBSCAN

# %%
nbrs = NearestNeighbors(n_neighbors=4).fit(df)
distances, indices = nbrs.kneighbors(df)

distances = np.mean(distances, axis=1)
distances = np.sort(distances)

plt.plot(distances)

# %%
dbscan = DBSCAN(eps=10 ,min_samples=4).fit(df)

plt.scatter(df[:,0], df[:,1], c=dbscan.labels_)
metric(dbscan.labels_,df,df_y)
# Out:
# Rand_Score:: 0.034663998221036246
# Completeness Score: 1.0
# Silhouette_score: 0.1603254962722954
# Davies-Bouldin Score: 2.223765451477158
